# %% [markdown]
# ---
#
# <div align='center'>
# <font size="+2">
#
# Text Mining and Natural Language Processing
# 2023-2024
#
# <b>SelectWise</b>
#
# Alessandro Ghiotto 513944
#
# </font>
# </div>
#
# ---

# %% [markdown]
# # Notebook 4 - LLM Prompting:
#
# - Zero-Shot Prompting
# - Zero-Shot Chain of Thought Prompting
# - Few-Shot Prompting
# - RAG inspired Few-Shot Prompting
#
# ---
#
# Data

# %%
from datasets import load_dataset
import pandas as pd
import numpy as np
import random
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import Dataset
sns.set_theme(style="darkgrid")

# SEED
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.random.manual_seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
seed = 8
set_seed(seed)

# DEVICE and DTYPE
mydevice = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.set_default_device(mydevice) # default tensor device
# torch.set_default_dtype(torch.float32) # default tensor dtype

# DATASET
dataset = load_dataset("allenai/qasc")
n_train_sample = 7323
dataset_train = dataset['train'].select(range(n_train_sample))
dataset_val = dataset['train'].select(range(n_train_sample, len(dataset['train'])))
dataset_test = dataset['validation']

def format_choices(example):
    if example['choices']['label'] == ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']:
        example['choices'] = example['choices']['text']
    else:
        print("The order of the choices is not the same for all the examples")
    example['answerKey_int'] = ord(example['answerKey']) - 65
    return example

dataset_train = dataset_train.map(format_choices)
dataset_val = dataset_val.map(format_choices)

# Display the dataset
dataset_train[0]
# Out:
# {'id': '3E7TUJ2EGCLQNOV1WEAJ2NN9ROPD9K',
#  'question': 'What type of water formation is formed by clouds?',
#  'choices': ['pearls',
#   'streams',
#   'shells',
#   'diamonds',
#   'rain',
#   'beads',
#   'cooled',
#   'liquid'],
#  'answerKey': 'F',
#  'fact1': 'beads of water are formed by water vapor condensing',
#  'fact2': 'Clouds are made of water vapor.',
#  'combinedfact': 'Beads of water can be formed by clouds.',
#  'formatted_question': 'What type of water formation is formed by clouds? (A) pearls (B) streams (C) shells (D) diamonds (E) rain (F) beads (G) cooled (H) liquid',
#  'answerKey_int': 5}

# %% [markdown]
# ---
#
# # LLM: `'DeciLM-7B-instruct'`
#
# <https://huggingface.co/Deci/DeciLM-7B-instruct>
#
# DeciLM-7B-instruct is a model for short-form instruction following. It is built by LoRA fine-tuning on the SlimOrca dataset.
#
# ![picture](../imgs/4_LLMprompting.png)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, pipeline

model_name = "Deci/DeciLM-7B-instruct"

device = "cuda" 

dtype_kwargs = dict(
    quantization_config=BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.bfloat16
))

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    trust_remote_code=True,
    **dtype_kwargs
)

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    temperature=0.1,
    top_p=0.9,
    do_sample=True,
    device_map="auto",
    max_new_tokens=256,
    return_full_text=False
)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# I follow the propt for this specific LLM:
#
# ```Python
# """
# ### System:
# You are an AI assistant that follows instruction extremely well. Help as much as you can.
# ### User:
# {propt}
# """
# ```

# %%
def get_response(user_prompt, pipeline=pipe):
    system_prompt = "You are an AI assistant that follows instruction extremely well. Help as much as you can."
    prompt = pipeline.tokenizer.apply_chat_template([
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ], tokenize=False, add_generation_prompt=True)
    return pipeline(prompt)[0]['generated_text']


system_prompt = "You are an AI assistant that follows instruction extremely well. Help as much as you can."
user_prompt = "How to train a dragon?"
prompt = tokenizer.apply_chat_template([
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt},
], tokenize=False, add_generation_prompt=True)

response = pipe(prompt)[0]['generated_text']
print(prompt + response)
# Out:
# ### System:
# You are an AI assistant that follows instruction extremely well. Help as much as you can.
# ### User:
# How to train a dragon?
# ### Assistant:
#  Training a dragon can be a complex and potentially dangerous task. However, here are some general steps that can be taken to train a dragon:
#
# 1. Establish a bond: Start by building a strong bond with the dragon. This can be done through positive interactions, such as feeding it, playing with it, and providing a safe and comfortable environment.
#
# 2. Teach basic commands: Once the dragon trusts you, you can begin teaching it basic commands, such as "come," "sit," and "stay."
#
# 3. Teach more advanced commands: As the dragon becomes more comfortable with you, you can teach it more advanced commands, such as "roll over," "jump through a hoop," and "fly."
#
# 4. Use positive reinforcement: When the dragon successfully completes a command, reward it with a treat or praise. This will encourage the dragon to continue learning and performing the commands.
#
# 5. Be patient and consistent: Training a dragon requires patience and consistency. Be patient with the dragon's learning process and consistently reinforce the commands you teach.
#
# 6. Seek professional help: If you're unsure about how to train a dragon, seek professional help from a dragon

# %% [markdown]
# ## **Zero-Shot Prompting**
#
# We directly ask the question in which we are interested
#
# ```Python
# f"""
# Question: {item['question']}
# fact1: {item['fact1']}
# fact2: {item['fact2']}
# A) {item['choices'][0]}
# B) {item['choices'][1]}
# ...
# H) {item['choices'][7]}
# Choose the correct choice. Answer with the corresponding letter only.
# """
# ```

# %%
import timeit

def evaluate_model(dataset, question_format, pipeline=pipe):
  total = 0
  correct = 0
  skipped = 0
  t0 = timeit.default_timer()
  # cicle over all the reviews
  for item in dataset:
    true_label = item["answerKey"]
    prompt = question_format(item)
    answer = get_response(prompt, pipeline)
    output_label = answer.upper().replace("\n", " ").strip()[0]
    # output_label = output_label.replace("ANSWER:", "").strip()[0]

    # if the answer is not in the choices, we skip
    if output_label not in ['A','B','C','D','E','F','G','H']:
      print(answer)
      skipped+=1 # counter of skipped sentences
      continue # we simply continue the loop

    if output_label == true_label: # CORRECT
      correct+=1
    total+=1

  print(f"elapsed : {timeit.default_timer()-t0:.2f} seconds")
  print(f"skipped : {skipped}")
  print(f"correct : {correct}")
  print(f"accuracy: {correct/total:.5f}")

# %%
def question_format_(item):
  question_format = f"""\
  Question: {item['question']}
  fact1: {item['fact1']}
  fact2: {item['fact2']}
  A) {item['choices'][0]}
  B) {item['choices'][1]}
  C) {item['choices'][2]}
  D) {item['choices'][3]}
  E) {item['choices'][4]}
  F) {item['choices'][5]}
  G) {item['choices'][6]}
  H) {item['choices'][7]}
  Choose the correct choice. Answer with the corresponding letter only."""
  return question_format

evaluate_model(dataset_val, question_format_)
# Out:
# /home/max/.pyenv/versions/3.12.3/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# elapsed : 186.94 seconds
# skipped : 0
# correct : 743
# accuracy: 0.91615

# %% [markdown]
# Since the information are read from left to right in Language Models (unlike BERT like models, in which each word look at any other word), can be interesting to look how the other of the elements in our sentence influence the performance.

# %%
# swap the order between the facts and the question

def question_format_(item):
  question_format = f"""\
  fact1: {item['fact1']}
  fact2: {item['fact2']}
  Question: {item['question']}
  A) {item['choices'][0]}
  B) {item['choices'][1]}
  C) {item['choices'][2]}
  D) {item['choices'][3]}
  E) {item['choices'][4]}
  F) {item['choices'][5]}
  G) {item['choices'][6]}
  H) {item['choices'][7]}
  Choose the correct choice. Answer with the corresponding letter only."""
  return question_format

evaluate_model(dataset_val, question_format_)
# Out:
# elapsed : 159.64 seconds
# skipped : 0
# correct : 780
# accuracy: 0.96178

# %% [markdown]
# The increase in the accuracy given by just changing the order of the facts and the question is incredible

# %%
# put together the facts and the question

def question_format_(item):
  question_format = f"""\
  Question: {item['fact1']}. {item['fact2']} {item['question']}
  A) {item['choices'][0]}
  B) {item['choices'][1]}
  C) {item['choices'][2]}
  D) {item['choices'][3]}
  E) {item['choices'][4]}
  F) {item['choices'][5]}
  G) {item['choices'][6]}
  H) {item['choices'][7]}
  Choose the correct choice. Answer with the corresponding letter only."""
  return question_format

evaluate_model(dataset_val, question_format_)
# Out:
# /home/max/.pyenv/versions/3.12.3/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# elapsed : 163.18 seconds
# skipped : 0
# correct : 740
# accuracy: 0.91245

# %%
# put together the choices

def question_format_(item):
  question_format = f"""\
  {item['fact1']}. {item['fact2']}
  Question: {item['question']}
  (A) {item['choices'][0]} (B) {item['choices'][1]} (C) {item['choices'][2]} (D) {item['choices'][3]} \
  (E) {item['choices'][4]} (F) {item['choices'][5]} (G) {item['choices'][6]} (H) {item['choices'][7]}
  Choose the correct choice. Answer with the corresponding letter only (i.e. A, B...)."""
  return question_format

evaluate_model(dataset_val, question_format_)
# Out:
#  (G)
#  (C) harmful substances
# elapsed : 154.66 seconds
# skipped : 2
# correct : 763
# accuracy: 0.94314

# %%
# move the instractions at the beginning

def question_format_(item):
  question_format = f"""\
  This is a multiple choice question, choose the correct choice. Answer with the corresponding letter only.
  fact1: {item['fact1']}
  fact2: {item['fact2']}
  Question: {item['question']}
  A) {item['choices'][0]}
  B) {item['choices'][1]}
  C) {item['choices'][2]}
  D) {item['choices'][3]}
  E) {item['choices'][4]}
  F) {item['choices'][5]}
  G) {item['choices'][6]}
  H) {item['choices'][7]}
  ANSWER:"""
  return question_format

evaluate_model(dataset_val, question_format_)
# Out:
# elapsed : 163.67 seconds
# skipped : 0
# correct : 774
# accuracy: 0.95438

# %% [markdown]
# The results are already very good, if we think that we have not trained the model, we are just using it out of the box. We have also to consider that requires much more time wrt BERT-like models. We can also say that DeciLM is very good at following what we have asked (no skipped answers).
#
# ## **Zero-Shot Chain of Thought Prompting**
#
# I ask the model to think about the answer, by saying "Let's think step by step"

# %%
# Let's think step by step

def question_format_(item):
  question_format = f"""\
  Let's think step by step.
  fact1: {item['fact1']}
  fact2: {item['fact2']}
  Question: {item['question']}
  A) {item['choices'][0]}
  B) {item['choices'][1]}
  C) {item['choices'][2]}
  D) {item['choices'][3]}
  E) {item['choices'][4]}
  F) {item['choices'][5]}
  G) {item['choices'][6]}
  H) {item['choices'][7]}
  Choose the correct choice and motivate your answer."""
  return question_format

evaluate_model(dataset_val, question_format_)
# Out:
# /home/max/.pyenv/versions/3.12.3/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
#  The correct choice is D) animals.
#
# Fight-or-flight is the same in humans and animals because both species exhibit a similar response to threatening situations. This response is a survival mechanism that helps them cope with danger.
#  The correct choice is E) adrenaline to surge.
#
# Animal attacking another animal may cause adrenaline to surge.
#
# This is because when an animal is threatened, it experiences a fight-or-flight response, which is a physiological reaction that prepares the animal to either fight or flee. This response is triggered by the release of adrenaline, a hormone produced by the adrenal glands. The adrenaline surge causes the animal's body to prepare for action, such as increased heart rate, blood flow to the muscles, and heightened senses.
#  The correct choice is E) Store it for later.
#
# The body stores calories for later use when it is not immediately used for energy. This is because calories are the energy stored in food, and the body needs them to maintain its functions and perform various activities.
#  The correct choice is H) iron.
#
# Minerals are chemical elements that are essential for body processes. Iron deficiency anemia is associated with low levels of the mineral iron in the body. Therefore, iron is a chemical element that is essential for body processes.
#  The correct choice is G) potassium.
#
# Minerals, like potassium, are essential for body processes. They are chemical elements that are necessary for various functions in the body, such as maintaining fluid balance, regulating nerve impulses, and supporting muscle contractions.
#  The correct choice is G) pregnancy.
#
# Minerals are essential for body processes, and pregnancy is a normal body process. Therefore, minerals are essential for pregnancy.
#  The correct choice is G) telephone.
#
# People can listen and talk to each other over long distances using a telephone. A telephone is a device used for communication by humans over long distances, and it enables both listening and talking. The other options, such as neuron, power, microscope, microphone, electricity, dictaphone, and waves, are not directly related to the act of communication over long distances using a telephone.
#  The correct choice is H) genitals.
#
# Adult worms go through a major transformation to develop reproductive organs, which are the genitals.
#  The correct choice is G) sponges.
#
# Adult sponges are attached permanently, immobile. This is supported by the fact that adult sponges are sessile, meaning they are attached to a surface and cannot move freely. The other options, such as eyes, bears, four limbs, insects, barnacles, salmon, and fungi, do not fit the description of being attached permanently, immobile.
#  The correct choice is E) adult sponges.
#
# Sedentary refers to organisms that are immobile or stay in one place. In the given facts, it is mentioned that most echinoderms are sessile or sedentary marine forms with radial symmetry as adults. Adult sponges are sessile, which means they are immobile and stay in one place. Therefore, the correct answer is E) adult sponges.
#  The correct choice is G) adult sponges.
#
# Adult sponges are attached permanently, immobile, and sessile. This means they are attached to a surface and cannot move freely. The other options are not attached permanently, or are not sessile.
#  The correct choice is B) immobile.
#
# Adult sponges are sessile, which means they are attached permanently and immobile. This is supported by fact2. The other options are not related to the given facts.
#  The correct choice is E) jaws.
#
# All vertebrates have jaws because they are all chordates, and all chordates have jaws. This is supported by the fact that vertebrates are all chordates that have a backbone.
#  The correct choice is E) mammals.
#
# Mammals are like other vertebrates that have a backbone. This is because they are chordates, which means they have a backbone. The other options, such as animals, sharks, vibrations, sound, alpacas, and bees, are not necessarily like other vertebrates with a backbone.
#  The correct choice is G) jaw and a backbone.
#
# All vertebrates have a backbone (G) and jaws (G), as stated in the facts provided. Vertebrates are all chordates, which means they have a backbone. Additionally, all chordates have jaws (G), which is a defining characteristic of vertebrates.
#  The correct choice is H) mammals.
#
# Vertebrates are a group of animals that includes mammals, birds, reptiles, amphibians, and fish. They are all chordates, which means they have a backbone or a notochord. The fact that mammals are like other chordates in having a backbone supports this classification.
#  The correct choice is E) mortality.
#
# Mortality refers to the death of individuals within a population. When mortality is greater, it means that more individuals are dying, which can lead to a decrease in the population. This is supported by the fact that harming an animal species causes that animal's population to decrease (fact1) and if mortality is greater, then the population decreases (fact2).
#
# The other options, such as wind, magma, bacteria, influenza, reproduction, and parasites, may have an impact on a population, but they do not directly cause a population decline through mortality.
#  The correct choice is G) goat.
#
# Goats are four-legged animals, and harming them can cause their population to decrease. This is in line with fact1. The other options are not four-legged animals or are not animals at all, so they cannot be harmed in the same way.
#  The correct choice is B) fur.
#
# Mammals have a layer of fur under their skin that is used to insulate the body. This fur helps to regulate their body temperature and protect them from the elements.
#  The correct choice is E) flow continuously.
#
# Powering an electrical device with a battery requires a path for electrons to flow continuously. This is because electrons flow continuously in a closed circuit, as stated in fact2. The other options are not related to the flow of electrons in a closed circuit.
#  The correct choice is E) electromagnetic energy.
#
# Upon entering the eye, light, which is the visible form of electromagnetic energy, falls on the retina. The retina then converts this light into electrical signals that are sent to the brain, where they are interpreted as visual information.
#  The correct choice is G) photons.
#
# Humans use photons to see an image. When light enters the eye through the pupil, it falls on the retina. The retina then converts the light into electrical signals that are sent to the brain, where they are interpreted as an image.
#  The correct choice is G) it can fluctuate.
#
# When animals begin to migrate, it can cause a change in population size and composition. This can lead to fluctuations in population size and species composition. This is because migration can cause animals to move from one area to another, which can affect the balance of the ecosystem. Therefore, the population can fluctuate in response to migration.
#  The correct choice is E) change in population size.
#
# When insects move from one place to another, this usually causes a change in population size. This is because migration can lead to the movement of individuals from one area to another, which can affect the overall population size.
#  The correct choice is G) Movement.
#
# Migration changes population size via movement. Movement is thought in motion, and migration is a type of movement that changes population size. Therefore, the correct answer is G) Movement.
#  The correct choice is H) insects.
#
# Insects can change population size through movement, as mentioned in fact2. They are a type of animal, and they migrate. Therefore, they can be a factor in changing population size through movement.
#  The correct choice is E) Reproduce.
#
# Insects, being arthropods, have a life cycle with sexual reproduction. This means that they go through a series of stages, including egg, larva, pupa, and adult. During their lifespan, insects reproduce by laying eggs, which hatch into larvae. The larvae then undergo a series of molts, shedding their skin as they grow, until they reach the pupa stage. After a period of time, the pupa transforms into an adult insect, which then mates and lays eggs to continue the cycle.
#  The correct choice is H) mixing genes up.
#
# Arthropods have a life cycle with sexual reproduction, which involves mixing genes up more than is possible with asexual reproduction. This is a key difference between the two types of reproduction.
#  The correct choice is E) long flights.
#
# Motivation:
#
# Astronauts, who are also space explorers, require preserved food for extended flights. This is because they often spend long periods of time in space, sometimes even months or years. Preserved food is essential for their survival and nutritional needs during these long flights.
#  The correct choice is G) jellyfish.
#
# Jellyfish and insects are invertebrates, which means they lack a backbone. The other options, such as fossil fuels, chlorophyll, humans, leptospirosis, fungi, and spine, are not invertebrates and do not lack a backbone.
#  The correct choice is G) backbones.
#
# Insects are invertebrates, which means they lack a vertebral column or backbone. This is fact1. Insects are the most common invertebrates, which is fact2. Therefore, insects don't have backbones.
#  The correct choice is G) support column.
#
# Invertebrates are animals that lack a support column, which is the vertebral column or backbone. This is because they do not have a vertebral column to support their spine.
#  The correct choice is E) a vertebral column.
#
# Millipedes lack a vertebral column, or backbone, which is a defining characteristic of invertebrates. This is supported by the fact that millipedes, spiders, and other invertebrates are probably taken as well.
#  The correct choice is C) gecko.
#
# Reasoning:
#
# Fact 1 states that invertebrates are animals that lack a vertebral column or backbone.
# Fact 2 states that geckos have backbones and are reptiles.
#
# Since geckos have backbones, they are not invertebrates. Therefore, the correct choice is C) gecko.
#  The correct choice is E) Insects.
#
# Invertebrates are animals that lack a vertebral column or backbone. Insects are the most common invertebrates. Therefore, insects are animals that lack a backbone.
#  The correct choice is G) Lakes.
#
# Mechanical weathering is a process that occurs when rocks and other materials are physically broken down by natural forces such as wind, water, and ice. This process can lead to the formation of lakes, such as Karakul, which is the largest of the glacier-formed lakes.
#  The correct choice is H) Pesticide exposure.
#
# Pesticide exposure refers to the situation when people get pesticides on or in the body. This exposure can have a negative impact on humans, as mentioned in fact1. The other options are not directly related to the question or are not accurate descriptions of pesticide exposure.
#  The correct choice is E) burning calories.
#
# Mammals generate heat mainly by burning calories. This is because their metabolic rate is high, and resting metabolic rate is a big contributor to calories burning. The other options are not accurate or relevant to the given facts.
#  The correct choice is G) Consuming calories.
#
# Mammals generate heat by maintaining a high metabolic rate, which means they consume more calories. This process is called thermoregulation, and it helps them maintain their body temperature within a specific range.
#  The correct choice is E) the vibrations of objects.
#
# Telephones are used for communication by two people by transmitting waves produced by the vibrations of objects. This is because the sound waves produced by the vibrations of objects are what are transmitted through the telephone system. The other options are not related to the transmission of sound waves through telephones.
#  The correct choice is G) Mechanical waves.
#
# Telephones are used for communication by two people by transmitting mechanical waves. This is because sound waves are mechanical waves, and telephones use sound waves to transmit information between two people.
#  The correct choice is E) Darkness.
#
# Darkness has a negative impact on photosynthesis, which is essential for plant growth. Therefore, darkness has a negative impact on plant growth.
#  The correct choice is E) solar eclipse.
#
# During a solar eclipse, the sky can get quite dark, which can have a negative impact on photosynthesis. Photosynthesis is the process by which plants convert light energy into chemical energy, and darkness can inhibit this process. The other options listed (A-H) are not directly related to the negative impact of darkness on photosynthesis.
#  The correct choice is G) DNA.
#
# To build cells, the human body needs DNA. DNA is the genetic material that makes up genes and is responsible for the inheritance of traits from parents to offspring. DNA contains the instructions for building cells, which are made up of proteins. Proteins are made by the human body using DNA as a template. Therefore, DNA is needed to build cells.
#  The correct choice is G) Lighting.
#
# Motivation:
#
# Wind is used for producing electricity, which is a form of power. We also need gas and electricity for heating and lighting. Therefore, lighting uses power.
#  The correct choice is D) produce electricity.
#
# Turbines are used to produce electricity. Wind turbines, which are windmills that generate electricity, are a specific type of turbine. Wind is used for producing electricity, as mentioned in fact1. Therefore, the most appropriate answer is D) produce electricity.
#  The correct choice is G) sound.
#
# A radio converts electrical energy into vibrations, which produce sound. Sound is a type of energy that travels in waves.
#  The correct choice is G) streams and creeks.
#
# Step 1: Understand the question and the given facts.
# The question asks what is better able to dissolve oxygen and nutrients than standing water.
#
# Step 2: Analyze the given facts.
# Fact1: Running water is better able to dissolve oxygen and nutrients than standing water.
# Fact2: Streams and creeks provide running water.
#
# Step 3: Match the facts to the answer choices.
# A) puddles - not running water
# B) microorganisms - not a type of water
# C) ponds - not running water
# D) nitrogen - not a type of water
# E) swamp vegetation - not a type of water
# F) Veins and arteries - not a type of water
# H) peachleaf willow - not a type of water
#
# Step 4: Choose the correct answer.
# G) streams and creeks - matches the given facts.
#  The correct choice is H2O (A).
#
# Running water dissolves oxygen better than standing water because running water has more oxygen-rich air in contact with it, which helps to dissolve oxygen and nutrients. In contrast, standing water has less oxygen-rich air in contact with it, making it less effective at dissolving oxygen and nutrients.
#
# The other options are not correct because:
#
# - NaCl (B) is the chemical formula for table salt (sodium chloride). It does not dissolve oxygen better when running than standing.
# - pH (C) is the measure of acidity or alkalinity of a solution. It does not dissolve oxygen better when running than standing.
# - CO2 (D) is carbon dioxide, a gas that is not directly related to oxygen dissolution.
# - CO (E) is carbon monoxide, a gas that is not directly related to oxygen dissolution.
# - O2 (F) is oxygen, which is the correct answer.
# - O3 (G) is ozone, a gas that is not directly related to oxygen dissolution.
# - H2O (H) is water, which is the correct
#  The correct choice is G) vessel walls.
#
# Blood pressure is the pressure on the blood vessel walls, and as mentioned in fact1, the pressure is highest in arteries and lowest in veins. Therefore, the pressure in vessel walls is highest in arteries and lowest in veins.
#  The correct choice is D) arteries.
#
# Blood pressure is highest in arteries because that is where the blood is being pumped out of the heart by the heart's contractions. The blood is then carried away by arteries to the rest of the body. The other options are not correct because they are not the location where blood pressure is highest.
#  The correct choice is F) away from the heart.
#
# Blood pressure is highest in arteries, which conduct blood away from the heart. This means that when blood pressure is highest, the blood is conducting away from the heart.
#  The correct choice is B) arteries.
#
# Motivation:
#
# Blood pressure is highest in arteries and lowest in veins. This means that the vessels that bring blood to the heart, which are the arteries, have lower blood pressure than the other options listed. The skin, archery, heat or cold, exercise, artefact, artesan, and lungs are not directly related to the flow of blood in the body.
#  The correct choice is G) lowest.
#
# Motivation:
#
# Blood pressure is highest in arteries and lowest in veins. This means that the pressure in veins is the lowest among all blood vessels. Therefore, the correct answer is G) lowest.
#  The correct choice is G) force.
#
# Blood pressure is the force of the blood on the artery walls. As mentioned in fact1, blood pressure is highest in arteries and lowest in veins. Therefore, the blood that is highest in arteries and lowest in veins is the force of the blood, which is option G.
#  The correct choice is G) blood goes to the heart.
#
# Blood pressure is lowest in veins, which take blood to the heart. This is because the blood in veins is returning to the heart after being oxygenated in the lungs or after being used by the body's tissues. The blood in arteries is being pumped out of the heart and is under pressure to be distributed to the rest of the body.
#  The correct choice is H) electric shock.
#
# Electrocution, which includes electric shock, causes harm to an organism. This is because the electric shock can disrupt the normal functioning of the body's cells and tissues, leading to damage or death. The other options, such as cuddles, cigarettes, viruses, causing love, warm covers, and influenza, do not directly cause harm to an organism in the same way that electrocution does.
#  The correct choice is D) animals.
#
# Electrocution causes harm to animals. This is because electrocution involves the passage of electric current through an organism's body, which can cause damage to the organism's cells and tissues. Both plants and animals are organisms, but electrocution specifically refers to harming animals.
#  The correct choice is E) animals.
#
# Powerlines cause harm to animals, specifically eagles, as mentioned in fact2. Electrocution is a form of harm to an organism, and eagles are electrocuted on powerlines. Therefore, powerlines cause harm to animals.
#  The correct choice is G) electricity.
#
# Electrocution causes harm to an organism. In this case, the harm is caused by the electricity. The other options are not related to the harm caused by electrocution.
#  The correct choice is G) mate.
#
# An animal needs to find a mate to ensure survival because it is a crucial part of reproduction. Reproduction is essential for the continuation of a species, and finding a mate is a necessary step in this process. The other options, such as disaster, warmth, food, space, predators, smell, and DNA, are not directly related to ensuring survival.
#  The correct choice is D) nitrogen oxides.
#
# Air pollution, including nitrogen oxides, can harm the respiratory and circulatory systems. This is because nitrogen oxides are a type of air pollutant that can cause respiratory and circulatory problems. The other options listed are not directly related to air pollution and its effects on the respiratory and circulatory systems.
#  The correct choice is G) SO2.
#
# Step 1: Understand the facts.
# Fact1: Air pollution harms the respiratory and circulatory systems.
# Fact2: Exposure to ozone can diminish lung function and increase susceptibility to respiratory infection.
#
# Step 2: Analyze the given options.
# A) Lead: Lead is a toxic metal that can cause various health problems, but it is not directly related to air pollution.
# B) Air: Air pollution is the general term for harmful substances in the air, but it does not specify which type of pollution is most harmful to lungs.
# C) Cars: While car emissions can contribute to air pollution, they are not the most harmful to lungs.
# D) Oil: Oil pollution is not directly related to air pollution and its effects on the lungs.
# E) Acid: Acid pollution is not directly related to air pollution and its effects on the lungs.
# F) CFCs: CFCs are a type of air pollution, but they are not the most harmful to lungs.
# G) SO2: SO2 (sulfur dioxide) is a type of air pollution that can directly harm
#  The correct choice is F) Bacteria.
#
# Motivation:
#
# Pathogens are microorganisms that can cause disease. They include bacteria, protozoans, and viruses. Bacteria are a type of pathogen that can cause disease. Therefore, the correct answer is F) Bacteria.
#  The correct choice is A) food.
#
# Some organisms need food to reproduce. In the case of birds, they need food to provide energy for their metabolic processes, which are necessary for reproduction.
#  The correct choice is D) peachleaf willow.
#
# Some birds are pollinators that co-evolved with peachleaf willow. This is because peachleaf willow is a plant that spreads by self-seeding and below ground stems. As birds are pollinators, they play a crucial role in the co-evolution process with peachleaf willow.
#  The correct choice is H) animals.
#
# Some birds with feathers are pollinators. Birds are animals, so the answer is animals.
#  The correct choice is E) hummingbirds.
#
# Hummingbirds are an important group of bird pollinators that have co-evolved with plants. This is supported by fact1 and fact2. The other options are not related to the question or are incorrect.
#  The correct choice is G) soil.
#
# Acid rain can change the acidity of soil and water, as mentioned in fact2. This change in acidity can have a negative impact on water quality, as stated in fact1. Therefore, acid rain can change the soil.
#  The correct choice is H) Habitat quality.
#
# Acid rain has a negative impact on water quality, which in turn affects habitat quality. This is because acid rain can make water more acidic, which can harm aquatic organisms and their habitats.
#  The correct choice is H) water quality.
#
# Precipitation detrimental to plant growth has a negative impact on water quality. This is because acid rain or acidic precipitation can lower the pH of water bodies, making them more acidic. This change in pH can harm aquatic organisms, including plants, and affect the overall health of the ecosystem.
#  The correct choice is G) sulfur dioxide.
#
# Water quality can be negatively affected by sulfur dioxide, as it is a major component of acid rain. Acid rain has a negative impact on water quality, and sulfur dioxide is a primary cause of acid rain.
#  The correct choice is E) cars and trucks.
#
# Motivation:
#
# Acid rain is a result of the emission of airborne pollutants, which are primarily emitted by cars and trucks. These pollutants, such as nitrogen oxides and sulfur dioxide, react with water, oxygen, and other substances in the atmosphere to form acidic compounds. When these compounds fall to the ground as precipitation, they can have a negative impact on water quality, as mentioned in fact1. Therefore, the worst effect on water quality is caused by cars and trucks (choice E).
#  The correct choice is F) invertebrates.
#
# Mollusks are a type of invertebrate, and some mollusks are nearly microscopic. Therefore, invertebrates are sometimes nearly microscopic.
#  The correct choice is C) Adaptation.
#
# Evolution occurs through a process called natural selection, which leads to adaptation. Adaptation is the result of natural selection. Therefore, adaptation leads to evolution.
#  The correct choice is E) speciation.
#
# Natural selection is a process of evolution that occurs when certain traits become more or less common in a population over time. Speciation is an extension of evolution, where new species arise from existing ones due to the accumulation of genetic changes over generations. These changes can be driven by natural selection, which is the mechanism that drives evolution.
#  The correct choice is D) environment.
#
# Variation is produced by the environment, which includes factors such as climate, geography, and other external factors. These factors influence the genetic makeup of organisms and lead to the variation in traits that are observed in evolution.
#  The correct choice is B) scattering seeds.
#
# Many plants respond to the days growing shorter by going dormant or scattering seeds and die. This is because the shorter days signal the end of the growing season, and the plants prepare for the upcoming winter by conserving energy and resources. Scattering seeds is a common strategy for plants to ensure their survival and reproduction in the next growing season.
#  The correct choice is H) animals.
#
# Zinc has a positive impact on the healing of wounds, which is a process that occurs in animals. Therefore, zinc has a positive impact on animals.
#  The correct choice is E) zinc.
#
# Zinc has a positive impact on the healing of wounds, and all wounds heal by scarring. Therefore, zinc has a positive impact on wounds scarring.
#  The correct choice is E) Harm hosts.
#
# Roundworms can be free-living or parasitic. As internal parasites, they harm their hosts in many ways. These parasitic roundworms can cause damage to their hosts, such as blocking their digestive tracts, causing inflammation, and even leading to death. This is why they are considered harmful to their hosts.
#  The correct choice is E) parasitic.
#
# Motivation:
#
# Step 1: Understand the question and the given facts.
# Fact1 states that roundworms can be free-living or parasitic.
# Fact2 states that nematodes are microscopic, true roundworms.
#
# Step 2: Analyze the given choices.
# A) dangerous - This is not a specific type of nematode.
# B) fungi - Nematodes are not fungi.
# C) parasites - This is a correct answer, as nematodes can be parasitic.
# D) flying - This is not a specific type of nematode.
# E) parasitic - This is a correct answer, as nematodes can be parasitic.
# F) warm-blooded - This is not a specific type of nematode.
# G) invincible - This is not a specific type of nematode.
# H) insects - Nematodes are not insects.
#
# Step 3: Choose the correct answer.
# The correct choice is E) parasitic.
#  The correct choice is H) streams in tropical regions.
#
# This is because fact1 states that Caecilians can be found in moist soil near rivers and streams in tropical regions. Fact2 states that Caecilians belong to the order Apoda or Gymnophiona. Therefore, members of the Apoda order can be found in streams in tropical regions.
#  The correct choice is E) gene sequences.
#
# Molecules of tRNA bring amino acids in the correct sequence, and gene sequences can only give the amino acid sequence that is translated by the ribosome. Therefore, gene sequences are the ones that bring amino acids in the correct sequence.
#  The correct choice is G) tRNA.
#
# Molecules of tRNA bring the building blocks of protein (amino acids) to the ribosomes in the correct sequence. This is a crucial step in protein synthesis, as it ensures that the amino acids are properly aligned and incorporated into the growing protein chain.
#  The correct choice is E) precipitation and run-off.
#
# Here's the step-by-step process of how a lake is formed:
#
# 1. Precipitation occurs, which is rain, snow, or other forms of water falling from the sky.
# 2. The water from precipitation accumulates on the surface of the land.
# 3. The water then flows downhill due to gravity, forming runoff.
# 4. The runoff collects in low-lying areas, such as valleys or basins.
# 5. Over time, the runoff accumulates and forms a body of water, which we call a lake.
#
# The other options are not directly related to the formation of a lake. Decomposition and respiration (A) are processes that occur within organisms, not in the formation of a lake. Storing water (B) is a result of the lake's formation, not a step in its formation. Photosynthesis and solar energy (C) are processes that occur in plants, not in the formation of a lake. Near the shoreline (D) is a characteristic of a lake, but not a step in its formation. Perspiration and excret
#  The correct choice is D) Mojave desert.
#
# Motivation:
#
# 1) Fact1: Lakes are formed by precipitation and runoff.
# 2) Fact2: A desert is defined by the scarcity of precipitation.
# 3) Combining these facts, we can deduce that a place with the least amount of precipitation is the least likely to have a lake.
# 4) The Mojave desert is known for its extreme aridity and lack of precipitation.
# 5) Therefore, the least likely place to find a lake is the Mojave desert (D).
#  The correct choice is C) Rain.
#
# Lakes are formed by precipitation and runoff, which includes rain. Rain is a type of precipitation, as mentioned in fact2. The other options listed are not directly related to the formation of lakes.
#  The correct choice is H) streams.
#
# Precipitation and runoff can result in large bodies of water, specifically in the form of streams. Lakes are large bodies of inland water, and they are formed by precipitation and runoff. Therefore, the combination of precipitation and runoff can lead to the formation of large bodies of water, such as streams.
#  The correct choice is C) wasted water.
#
# Lakes are formed by precipitation and runoff, which is wasted water. This means that the water in lakes is not being used for other purposes, such as drinking or agriculture, and is instead being stored in the lake. The other options, such as scarce resources, storing water, body water, bodily water, erosion, flooding, and reduced heat, are not directly related to the formation of lakes.
#  The correct choice is D) Coal.
#
# Coal is formed from dead organisms over time through the process of fossilization. The other options are not formed from dead organisms over time. Soil is formed from the weathering and decomposition of rocks and organic matter. Granite is a type of igneous rock formed from cooling magma. Coral is formed from the accumulation of calcium carbonate in the shells of marine organisms. Potash is a type of potassium salt. Ferns are a type of plant. Rust is a form of corrosion that occurs when iron or steel reacts with oxygen in the air.
#  The correct choice is E) oil.
#
# Fossil fuels are formed from dead organisms over time, and oil is one type of fossil fuel. The other options listed are not formed from dead organisms over time. Insects (A), water (B), plants (C), moss (D), and peat (F) are all living organisms or organic materials, not dead organisms. Gas (G) is a general term that can refer to various substances, but it does not specifically refer to fossil fuels. Coal (H) is a type of fossil fuel, but it is not the only type.
#  The correct choice is E) dead organisms.
#
# Petroleum is a fossil fuel, and fossil fuels are formed from dead organisms over time. This process involves the decomposition of organic matter, which then undergoes a series of chemical reactions and transformations to form hydrocarbons, the main components of petroleum.
#  The correct choice is E) Global climate change.
#
# The use of oil, gas, and coal contributes to global climate change. This is because the combustion of these fossil fuels releases gases such as carbon dioxide and methane, which trap heat in the atmosphere and lead to global warming. This global warming has significant impacts on the environment and climate, including rising sea levels, melting glaciers, and more extreme weather events.
#  The correct choice is D) coal.
#
# Global warming is primarily caused by the release of greenhouse gases, such as carbon dioxide, methane, and water vapor, into the atmosphere. These gases trap heat and cause the Earth's temperature to rise. Fossil fuels, including coal, oil, and natural gas, are the primary sources of these greenhouse gases when burned for energy. Therefore, coal is a significant contributor to global warming.
#  The correct choice is E) oil.
#
# Gases released during the use of oil, which is a fossil fuel, causes global warming. This is because oil is a major contributor to greenhouse gas emissions, particularly carbon dioxide (CO2).
#  The correct choice is G) oil.
#
# Gases released from the use of oil, a fossil fuel, causes global warming. This is because oil is a hydrocarbon, which when burned, releases carbon dioxide (CO2) and other greenhouse gases into the atmosphere. These gases trap heat and contribute to the greenhouse effect, leading to global warming.
#  The correct choice is B) Fossil fuels.
#
# Ice storms are caused by global warming, which is caused by the release of gases during the use of fossil fuels. Therefore, the use of fossil fuels is the primary cause of ice storms.
#  The correct choice is G) energy.
#
# Silver sage is a plant, and according to fact1, plants use unsaturated fatty acids to store energy. Therefore, silver sage may use unsaturated fatty acids to store energy.
#  The correct choice is B) Storing sunlight.
#
# Plants use unsaturated fatty acids to store energy, and sunlight is turned into energy by plants. Therefore, plants use unsaturated fatty acids to store sunlight.
#  The correct choice is G) cactus.
#
# Cactus and sagebrush are examples of plants that use unsaturated fatty acids to store energy. This is because they are adapted to survive in harsh environments with limited water availability. By storing energy in the form of unsaturated fatty acids, they can maintain their metabolic processes even when water is scarce.
#  The correct choice is G) share properties.
#
# Plants and fish oils share properties, as both contain unsaturated fatty acids. This is because plants use unsaturated fatty acids to store energy, and fish oils contain highly unsaturated fatty acids. Therefore, they have a common characteristic in their composition.
#  The correct choice is E) cancer cells.
#
# Antibodies are large, Y-shaped proteins that recognize and bind to antigens. Antigens are expressed by cancer cells. Therefore, antibodies recognize and bind to cancer cells.
#  The correct choice is H) antigens.
#
# Proteins, specifically antibodies, fight antigens. Antibodies are large, Y-shaped proteins that recognize and bind to antigens. They are produced to fight antigens, which are foreign substances that can trigger an immune response in the body.
#  The correct choice is E) immunogens.
#
# Antibodies are large, Y-shaped proteins that recognize and bind to antigens. Fact 2 states that all immunogens are antigens. Therefore, antibodies can recognize and bind to immunogens.
#  The correct choice is E) foreign proteins. Antibodies are designed to bind with foreign proteins, called antigens.
#  The correct choice is G) reproduce by themselves.
#
# Myocarditis is often caused by viruses, which cannot reproduce by themselves. This means that the cause of myocarditis cannot reproduce by themselves.
#  The correct choice is H) multiply.
#
# Viruses cannot do H) multiply by themselves. This is because viruses are not living organisms and cannot reproduce on their own. They rely on host cells to replicate and reproduce. Passwords, on the other hand, are not living organisms and cannot reproduce by themselves either. They are simply a sequence of characters that can be copied and shared.
#  The correct choice is D) influenza.
#
# Influenza is a disease caused by viruses, as mentioned in fact2. According to fact1, viruses cannot reproduce by themselves. Therefore, influenza, being a disease caused by viruses, cannot reproduce by itself. The other options listed are not diseases caused by viruses and can reproduce by themselves.
#  The correct choice is G) rabies.
#
# Viruses cannot reproduce by themselves, and rabies is an example of a virus. The other options listed are not viruses and do not fit the description given.
#  The correct choice is H) disease.
#
# The smallest agents of disease, such as viruses, cannot reproduce by themselves. This is because they rely on host cells to replicate and produce new viral particles.
#  The correct choice is G) Freshwater habitats.
#
# Mollusks, including clams, live in various habitats such as terrestrial, freshwater, and marine environments. Clams, being mollusks, live in the sea or freshwater habitats. Therefore, the correct answer is G) Freshwater habitats.
#  The correct choice is G) biomes.
#
# Mollusks live in most terrestrial, freshwater, and marine habitats, which are the world's major habitats known as biomes.
#  The correct choice is E) non-sustainable.
#
# Burning fossil fuels, such as coal, oil, and natural gas, increases the carbon in the atmosphere. This is because fossil fuels are non-sustainable, meaning they are finite resources that will eventually run out. When these fuels are burned, they release carbon dioxide and other greenhouse gases into the atmosphere, contributing to climate change and air pollution.
#  The correct choice is E) chlorine bleach.
#
# Chlorine bleach is ideal for treating water because it effectively removes harmful substances before drinking. This is a step-by-step process:
#
# 1. Fact 1: Treating water is used to remove harmful substances before drinking.
# 2. Fact 2: Chlorine bleach is ideal for treating water.
# 3. Combining these facts, we can conclude that chlorine bleach removes harmful substances from water before drinking.
#  The correct choice is G) Negative impact on survival.
#
# Cancer can have a negative impact on survival, as it can cause harm to an organism's cells and tissues, leading to a decrease in overall health and well-being. This negative impact can result in a decreased ability to survive and thrive in various environments.
#  The correct choice is G) chlorophyll.
#
# Animals lack chlorophyll, which is a pigment found in chloroplasts of plant cells. Chloroplasts are organelles that contain chlorophyll and are responsible for photosynthesis in plants. Since animals do not have chloroplasts, they do not contain chlorophyll.
#  The correct choice is G) green pigment chlorophyll.
#
# Animals lack the green pigment chlorophyll, which is found in chloroplasts. Chloroplasts are organelles found in plant cells that contain the green pigment chlorophyll, which is responsible for photosynthesis. Since animals do not have chloroplasts, they lack the green pigment chlorophyll.
#  The correct choice is E) chlorophyll.
#
# Animals lack chlorophyll, which is a pigment found in chloroplasts of plant cells. Chloroplasts are organelles that contain chlorophyll and are responsible for photosynthesis, the process by which plants convert sunlight into energy. Since animals do not have chloroplasts, they lack the ability to perform photosynthesis and produce their own food through this process.
#  The correct choice is C) chloroplasts.
#
# Fungi lack the green pigment chlorophyll, which is found in chloroplasts. Chloroplasts are organelles found in plant cells that contain chlorophyll, the green pigment responsible for photosynthesis. Fungi, on the other hand, lack chlorophyll and are nonphotosynthetic.
#  The correct choice is H) chloroplasts.
#
# Chloroplasts are organelles found in the cells of plants and algae that contain the green pigment chlorophyll. This pigment is responsible for the green color of leaves and is involved in the process of photosynthesis. The other options listed are not directly related to the presence of chlorophyll or the function of chloroplasts.
#  The correct choice is H) Deaf.
#
# Deaf people are those who cannot sense sound. This is because they have a hearing impairment, which means they cannot hear anything. The other options are not related to the inability to sense sound. Anosmic refers to a lack of sense of smell, ill is a general term for being unwell, mute refers to being unable to speak, frogs are a type of animal, blind refers to a lack of sight, and rabies is a disease.
#  The correct choice is D) humans.
#
# Humans are animals, and hearing is used for sensing sound by animals. Therefore, humans use hearing to sense sound.
#  The correct choice is D) Animals.
#
# Animals use their ears to hear. This is because hearing is used for sensing sound by animals, and sound waves enter the ear, and are then amplified.
#  The correct choice is H) functioning ears.
#
# In animals, hearing is used for sensing sound, and hearing requires functioning ears. Therefore, functioning ears are used for sensing sound in animals.
#  The correct choice is D) decibels.
#
# Animals can sense decibels, which is the degree of loudness required to hear the sound. Hearing is used for sensing sound by animals, and decibels are the unit of measurement for sound intensity. The other options, such as a pathogens, temperature, hormones, mitosis, heat, erosion, and decomposition, are not related to the ability of animals to sense sound.
#  The correct choice is C) Sensing sound.
#
# An ear improves hearing, which is used for sensing sound by animals. Therefore, an ear improves the ability to sense sound.
#  The correct choice is G) ears.
#
# Most animals have ears, which are used for sensing sound. Ears improve hearing, and hearing is used for sensing sound. Therefore, based on the given facts, it can be concluded that most animals have ears.
#  The correct choice is E) Instructions.
#
# At conception, a person inherits DNA, which contains instructions encoded in molecules of DNA. These instructions tell cells what to do, and they are responsible for the development and functioning of an individual's body and characteristics.
#  The correct choice is B) deoxyribonucleic acid (DNA).
#
# Molecules of DNA are encoded with instructions that tell cells what to do. DNA is deoxyribonucleic acid. Therefore, DNA is the molecule that is encoded with instructions that tell cells what to do.
#  The correct choice is H) deoxyribonucleic acid (DNA).
#
# Molecules of DNA are encoded with instructions that tell cells what to do. DNA is deoxyribonucleic acid. Therefore, DNA is the molecule that is encoded with instructions that tell cells what to do.
#  The correct choice is B) proteins.
#
# Molecules of DNA are encoded with instructions that tell cells what to do. DNA encodes the information for protein sequences. Therefore, proteins tell a cell what to do.
#  The correct choice is D) A person's genetic fingerprint.
#
# Molecules of DNA are encoded with instructions that tell cells what to do. DNA DNA DNA is a person's genetic fingerprint. Therefore, molecules of DNA are encoded with instructions that tell cells what to do.
#  The correct choice is E) electricity.
#
# Burning garbage can be used to produce electricity. This is because biofuels, which include garbage, are used to produce electricity by burning.
#  The correct choice is B) a sperm and an egg.
#
# Fertilization occurs when a sperm and an egg fuse, and after fertilization, the egg becomes diploid and is called a zygote. Therefore, a zygote forms when a sperm and an egg fuse.
#  The correct choice is H) sperm.
#
# Timing is critical for what occurs when a sperm and an egg fuse. The correct answer is H) sperm because fertilization occurs when a sperm and an egg fuse. The other options are not related to the process of fertilization.
#  The correct choice is H) Cephalopod.
#
# Cephalopods are a class of mollusks that includes squid, octopuses, and cuttlefish. They have separate sexes and fertilization occurs internally. This means that the sperm and egg fuse inside the female's body, rather than externally like in insects or barnacles. Therefore, cephalopods are the type of mollusk that inseminate the sperm and egg internally.
#  The correct choice is E) being outside during the day.
#
# Chlorine dissipates rapidly by sunlight, as stated in fact2. Fact1 states that if something is outside during the day, it will receive sunlight. Therefore, being outside during the day makes chlorine dissipate rapidly.
#  The correct choice is D) outside.
#
# Motivation:
#
# Fact1 states that if something is outside during the day, it will receive sunlight. Direct sunlight is harmful to paintings, as stated in Fact2. Therefore, placing paintings where they receive direct sunlight (outside) is harmful to them. The other options (A, B, C, E, F, G, and H) do not directly relate to the harmful effects of sunlight on paintings.
#  The correct choice is E) energy from the sun.
#
# If something is outside during the day, it will receive energy from the sun in the form of sunlight. This energy is in the form of photons and wavelengths, which are the basic units of light. The energy from the sun is what allows the sunlight to reach the object, and it is this energy that is responsible for the object receiving sunlight.
#  The correct choice is E) cholesterol.
#
# Steroids are derivatives of cholesterol. This is because steroid hormones, which are lipids, are made of cholesterol and other lipids such as phospholipids. Steroids are a type of lipid, and they are derived from cholesterol.
#  The correct choice is E) magnified.
#
# An electron microscope is used for seeing things magnified. This is because an electron microscope uses a magnification technique to make very small objects appear bigger. The magnification process increases the apparent size of an object, allowing for a more detailed and clearer view of the object.
#  The correct choice is E) a magnifying glass.
#
# Motivation:
#
# An electron microscope is a type of microscope that uses electron beams to magnify and visualize very small objects. It is an advanced and expensive type of microscope. On the other hand, a magnifying glass is a simple and inexpensive tool that uses lenses to magnify and visualize small objects. Therefore, a magnifying glass can make small objects seem bigger.
#  The correct choice is G) very small objects.
#
# Magnifying objects hundreds of thousands of times is used for seeing very small objects. An electron microscope is a tool that allows scientists to magnify objects to this level of detail, making them appear bigger. This is why it is used for seeing very small objects.
#  The correct choice is E) microscope.
#
# An electron microscope is a tool that can make things appear larger by using electrons to create images of very small objects. This is different from the other options listed, which are either not related to making things appear larger or are not tools used for this purpose.
#  The correct choice is E) Sunlight.
#
# All plants require sunlight for survival because sunlight is turned into energy by plants through the process of photosynthesis. This energy is then used by plants for their growth, reproduction, and overall survival. The other options, such as salinity, warm climate, nutrients, thirst, firm soil, fresh pollen, and proteins, are not directly related to the survival of plants.
#  The correct choice is H) trees.
#
# Motivation:
#
# 1) Fact 1 states that living things all require energy for survival.
# 2) Fact 2 states that trees are the largest of living things.
# 3) Combining these two facts, we can conclude that trees, being the largest of living things, also require energy for survival.
# 4) Therefore, the correct choice is H) trees.
#  The correct choice is B) Kinetic.
#
# Living things use kinetic energy, which is energy in motion. This energy is used for various purposes such as movement, growth, reproduction, and maintaining body temperature. The other options are not related to the motion used by living things.
#  The correct choice is H) trait.
#
# Living things all require energy conservation as a trait. Energy conservation is an important survival trait.
#  The correct choice is B) Malpighian tubules.
#
# Organs of excretion are composed of a dorsal excretory gland and a pair of Malpighian tubules. The Malpighian tubules are part of the excretory system, which is responsible for removing waste products and excess water from the body.
#  The correct choice is G) water.
#
# Graduated cylinders are used to measure the volume of a liquid, and water is also a liquid. Therefore, graduated cylinders can measure the volume of water. The other options, such as blood, vapors, alcohol, stars, the Moon, and atoms, are not liquids and cannot be measured using a graduated cylinder.
#  The correct choice is F) water.
#
# A graduated cylinder is used to measure the volume of a liquid, and most of the earth's water is liquid. Therefore, the volume of water can be measured with a graduated cylinder. The other options, such as vinegar, milk, vapors, ruler, blood, gas, and rocks, are not liquids and cannot be measured with a graduated cylinder.
#  The correct choice is D) mL.
#
# A graduated cylinder is used to measure volume of a liquid, and students learn to use a graduated cylinder and measure in mL. Therefore, the unit of measure that a cylinder measures volumes of liquid in is milliliters (mL).
#  The correct choice is H) Gasoline.
#
# A graduated cylinder is a measuring tool used to determine the volume of a liquid. Gasoline is an example of a liquid mixture, which can be measured using a graduated cylinder. The other options, such as rain, water vapor, bodily water, water, blood, and ocean water, are not liquids and cannot be measured using a graduated cylinder.
#  The correct choice is E) measuring volume of water.
#
# Graduated cylinders are used to measure the volume of a liquid, and water is also a liquid. Therefore, graduated cylinders can be used for measuring the volume of water.
#  The correct choice is E) camouflage.
#
# Scaled animals use scales for camouflage and protection. Scales provide a hard, protective covering that helps them blend into their environment, making them less visible to predators. This adaptation is an example of natural selection, as animals with better camouflage are more likely to survive and reproduce.
#  The correct choice is F) shells.
#
# Motivation:
#
# 1) Fact1: Scales are used for protection by scaled animals.
# 2) Fact2: Horned lizards are reptiles with tails and a scaled body.
# 3) Combining Fact1 and Fact2, we can infer that scales are used for protection by horned lizards.
# 4) Therefore, the correct choice is F) shells, as they provide protection to lizards.
#  The correct choice is D) Fish.
#
# Chitin is a substance found in the scales of fish, which they use for protection. This is supported by fact1 and fact2. The other options are not related to the use of chitin for protection.
#  The correct choice is H) fish.
#
# Motivation:
#
# Step 1: Identify the relevant facts.
# Fact1: Scales are used for protection by scaled animals.
# Fact2: Fish are covered with scales.
#
# Step 2: Analyze the question.
# The question asks what is covered with protection.
#
# Step 3: Match the facts with the question.
# Fact1 and Fact2 both mention scales and protection.
#
# Step 4: Choose the correct answer.
# Based on the analysis, the correct choice is H) fish, as they are covered with scales and use them for protection.
# elapsed : 2019.52 seconds
# skipped : 159
# correct : 630
# accuracy: 0.96626

# %%
# specify better how to answer

def question_format_(item):
  question_format = f"""\
  Let's think step by step.
  fact1: {item['fact1']}
  fact2: {item['fact2']}
  Question: {item['question']}
  A) {item['choices'][0]}
  B) {item['choices'][1]}
  C) {item['choices'][2]}
  D) {item['choices'][3]}
  E) {item['choices'][4]}
  F) {item['choices'][5]}
  G) {item['choices'][6]}
  H) {item['choices'][7]}
  Give the correct choice and a short motivation. start the sentence with the letter of the choice."""
  return question_format

evaluate_model(dataset_val, question_format_)
# Out:
# /home/max/.pyenv/versions/3.12.3/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# elapsed : 1730.24 seconds
# skipped : 0
# correct : 773
# accuracy: 0.95314

# %% [markdown]
# The time required by this method is much higher, because when we are asking the rationale of the answer, we ask the model to generate more token. And each token is generated sequentially, so the time required increases.

# %% [markdown]
# ## **Few-Shot Prompting**
#
# We give one example (or more), as a pattern to be followed by the model to give the answer.
#
# ```Python
# f"""
# Input: {text_1}
# Output: {label_1}
#
# ...
#
# Input: {text_n}
# Output: {label_n}
#
# Input: {target_text}
# Output:
# """
# ```

# %%
# one example

def question_format_(item, examples):
    # examples : list of items 
    question_format = ""
    for example in examples:
        question_format += f"""\
    fact1: {example['fact1']}
    fact2: {example['fact2']}
    Question: {example['question']}
    A) {example['choices'][0]}
    B) {example['choices'][1]}
    C) {example['choices'][2]}
    D) {example['choices'][3]}
    E) {example['choices'][4]}
    F) {example['choices'][5]}
    G) {example['choices'][6]}
    H) {example['choices'][7]}
    Answer: {example['answerKey']}\n\n"""

    question_format += f"""\
    fact1: {item['fact1']}
    fact2: {item['fact2']}
    Question: {item['question']}
    A) {item['choices'][0]}
    B) {item['choices'][1]}
    C) {item['choices'][2]}
    D) {item['choices'][3]}
    E) {item['choices'][4]}
    F) {item['choices'][5]}
    G) {item['choices'][6]}
    H) {item['choices'][7]}
    Answer:"""
    return question_format

examples = [dataset_train[0]]
question_format_train0 = lambda item : question_format_(item, examples)
evaluate_model(dataset_val, question_format_train0)
# Out:
# /home/max/.pyenv/versions/3.12.3/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# elapsed : 177.33 seconds
# skipped : 0
# correct : 790
# accuracy: 0.97411

# %% [markdown]
# I didn't specified anything, what was the task and what to answer. But with just one example the model given all valid answers (no skipped)

# %%
# try with 2 examples

examples = [dataset_train[0], dataset_train[10]]
question_format_train0 = lambda item : question_format_(item, examples)
evaluate_model(dataset_val, question_format_train0)
# Out:
# /home/max/.pyenv/versions/3.12.3/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# elapsed : 195.24 seconds
# skipped : 0
# correct : 784
# accuracy: 0.96671

# %% [markdown]
# More examples are not needed, since the model already understand the task with one example

# %%
# specify differently the examples

def question_format_(item, examples):
    # examples : list of items 
    question_format = ""
    for example in examples:
        question_format += f"""\
    INPUT:
        fact1: {example['fact1']}
        fact2: {example['fact2']}
        Question: {example['question']}
        A) {example['choices'][0]}
        B) {example['choices'][1]}
        C) {example['choices'][2]}
        D) {example['choices'][3]}
        E) {example['choices'][4]}
        F) {example['choices'][5]}
        G) {example['choices'][6]}
        H) {example['choices'][7]}
    OUTPUT: {example['answerKey']}\n\n"""

    question_format += f"""\
    INPUT:
        fact1: {item['fact1']}
        fact2: {item['fact2']}
        Question: {item['question']}
        A) {item['choices'][0]}
        B) {item['choices'][1]}
        C) {item['choices'][2]}
        D) {item['choices'][3]}
        E) {item['choices'][4]}
        F) {item['choices'][5]}
        G) {item['choices'][6]}
        H) {item['choices'][7]}
    OUTPUT:"""
    return question_format

examples = [dataset_train[0]]
question_format_train0 = lambda item : question_format_(item, examples)
evaluate_model(dataset_val, question_format_train0)
# Out:
# elapsed : 169.38 seconds
# skipped : 0
# correct : 784
# accuracy: 0.96671

# %% [markdown]
# With just a simple example we increased a little bit the accuracy, without increasing the time required too much.

# %% [markdown]
# ## **RAG inspired Few-Shot Prompting**
#
# I don't simply give a random example as context, but instead for each question I search a similar question to be given as context.
#
# The example is chosen in the train dataset. I choose the one which has the highest **cosine similarity** on the **tf-idf** representation. I preprocess the sentences before of computing the tf-idf weighting

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string

nltk.download('punkt')
nltk.download('stopwords')
stopwords_list = set(stopwords.words('english'))
punctuations = set(string.punctuation)
porter = PorterStemmer()

def nltk_tokenizer(sentence):
    # Lowercase all sentences
    sentence = sentence.lower()

    # Tokenize using nltk
    my_tokenized_tokens = word_tokenize(sentence)

    # Removing stop words and punctuations
    mytokens = [word for word in my_tokenized_tokens if word not in stopwords_list and word not in punctuations]

    # Stemming
    mytokens = [porter.stem(word) for word in mytokens]

    # join the tokens back into a single string
    sentence_preprocessed = ' '.join(mytokens)

    return sentence_preprocessed
# Out:
# [nltk_data] Downloading package punkt to /home/max/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/max/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Train the tf-idf representation on the questions only

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tokenized_sentences = [nltk_tokenizer(sentence) for sentence in dataset_train['question']]

tfidf_vectorizer = TfidfVectorizer()
tfidf_train = tfidf_vectorizer.fit_transform(tokenized_sentences)

tfidf_train.shape
# Out:
# (7323, 2710)

# %%
import scipy

def question_format_fewshot(item, examples):
    # examples : list of items 
    question_format = ""
    for example in examples:
        question_format += f"""\
    fact1: {example['fact1']}
    fact2: {example['fact2']}
    Question: {example['question']}
    A) {example['choices'][0]}
    B) {example['choices'][1]}
    C) {example['choices'][2]}
    D) {example['choices'][3]}
    E) {example['choices'][4]}
    F) {example['choices'][5]}
    G) {example['choices'][6]}
    H) {example['choices'][7]}
    Answer: {example['answerKey']}\n\n"""

    question_format += f"""\
    fact1: {item['fact1']}
    fact2: {item['fact2']}
    Question: {item['question']}
    A) {item['choices'][0]}
    B) {item['choices'][1]}
    C) {item['choices'][2]}
    D) {item['choices'][3]}
    E) {item['choices'][4]}
    F) {item['choices'][5]}
    G) {item['choices'][6]}
    H) {item['choices'][7]}
    Answer:"""
    return question_format


def cosine_similarity_btw2vec(v1, v2):
    # Check if the vectors are sparse matrices
    if scipy.sparse.issparse(v1):
        v1 = v1.toarray().flatten()
    if scipy.sparse.issparse(v2):
        v2 = v2.toarray().flatten()
    dot_product = np.dot(v1, v2)
    norm_v1 = np.linalg.norm(v1)
    norm_v2 = np.linalg.norm(v2)
    if norm_v1 == 0 or norm_v2 == 0:
        return 0.0 
    return dot_product / (norm_v1 * norm_v2)

# %%
total = 0
correct = 0
skipped = 0
t0 = timeit.default_timer()
# cicle over all the reviews
for item in dataset_val:
    true_label = item["answerKey"]

    # get the most similar example
    question = nltk_tokenizer(item["question"])
    question_tfidf = tfidf_vectorizer.transform([question])
    cos_similarity = [cosine_similarity_btw2vec(tfidf_train[i], question_tfidf) for i in range(tfidf_train.shape[0])]
    most_similar_example = np.argmax(cos_similarity)
    example = [dataset_train[int(most_similar_example)]]

    prompt = question_format_fewshot(item, example)
    answer = get_response(prompt, pipeline=pipe)
    output_label = answer.upper().replace("\n", " ").strip()[0]

    # if the answer is not in the choices, we skip
    if output_label not in ['A','B','C','D','E','F','G','H']:
        print(answer)
        skipped+=1 # counter of skipped sentences
        continue # we simply continue the loop

    if output_label == true_label: # CORRECT
        correct+=1
    total+=1

print(f"elapsed : {timeit.default_timer()-t0:.2f} seconds")
print(f"skipped : {skipped}")
print(f"correct : {correct}")
print(f"accuracy: {correct/total:.5f}")
# Out:
# /home/max/.pyenv/versions/3.12.3/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# elapsed : 353.71 seconds
# skipped : 0
# correct : 782
# accuracy: 0.96424

# %% [markdown]
# Compute tf-idf on `'question' + 'fact1' + 'fact2' + choices` instead of just the question

# %%
def get_full_text(item):
    return item['fact1'] + " " + item['fact2'] + " " + item['question'] + " " + " ".join(item['choices'])

full_text_sentences = []
for item in dataset_train:
    full_text_sentences.append(get_full_text(item))

tokenized_sentences = [nltk_tokenizer(sentence) for sentence in full_text_sentences]

tfidf_vectorizer = TfidfVectorizer()
tfidf_train = tfidf_vectorizer.fit_transform(tokenized_sentences)

tfidf_train.shape
# Out:
# (7323, 6286)

# %%
total = 0
correct = 0
skipped = 0
t0 = timeit.default_timer()

for item in dataset_val:
    true_label = item["answerKey"]

    # get the most similar example
    full_text = nltk_tokenizer(get_full_text(item))
    text_tfidf = tfidf_vectorizer.transform([full_text])
    cos_similarity = [cosine_similarity_btw2vec(tfidf_train[i], text_tfidf) for i in range(tfidf_train.shape[0])]
    most_similar_example = np.argmax(cos_similarity)
    example = [dataset_train[int(most_similar_example)]]

    prompt = question_format_fewshot(item, example)
    answer = get_response(prompt, pipeline=pipe)
    output_label = answer.upper().replace("\n", " ").strip()[0]

    # if the answer is not in the choices, we skip
    if output_label not in ['A','B','C','D','E','F','G','H']:
        print(answer)
        skipped+=1 # counter of skipped sentences
        continue # we simply continue the loop

    if output_label == true_label: # CORRECT
        correct+=1
    total+=1

print(f"elapsed : {timeit.default_timer()-t0:.2f} seconds")
print(f"skipped : {skipped}")
print(f"correct : {correct}")
print(f"accuracy: {correct/total:.5f}")
# Out:
# /home/max/.pyenv/versions/3.12.3/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# elapsed : 369.51 seconds
# skipped : 0
# correct : 777
# accuracy: 0.95808

# %% [markdown]
# At the end we didn't gain anything by trying to give a more suiteable example for each prompt.

# %% [markdown]
# ---
#
# ### **Best result notebook 4 -> Few-Shot Prompting**
#
# With the following prompt, for each item in the dataset. As context we have just one example (`dataset_train[0]`)
#
# ```Python
# f"""
#     fact1: beads of water are formed by water vapor condensing
#     fact2: Clouds are made of water vapor.
#     Question: What type of water formation is formed by clouds?
#     A) pearls
#     B) streams
#     C) shells
#     D) diamonds
#     E) rain
#     F) beads
#     G) cooled
#     H) liquid
#     Answer: F
#
#     fact1: {item['fact1']}
#     fact2: {item['fact2']}
#     Question: {item['question']}
#     A) {item['choices'][0]}
#     B) {item['choices'][1]}
#     C) {item['choices'][2]}
#     D) {item['choices'][3]}
#     E) {item['choices'][4]}
#     F) {item['choices'][5]}
#     G) {item['choices'][6]}
#     H) {item['choices'][7]}
#     Answer:
# """
# ```
#
# | Metric          | Validation |
# |-----------------|------------|
# | Accuracy        | $0.97411$  |
#
# The results are very good, if we consider also that we didn't train antything. But encoder only models like BERT are more suited for single-label classification tasks like this one. For two reasons:
#
# - requires less resources
# - it gives always a valid output, follows always what we want
